# %% [markdown]
# # Natural Language Processing Challenge

# %% [markdown]
# ## Model: Bag of words

# %%
#import sys
#sys.path.append('/content/sample_data')

# %%
# import here
import importlib
import helper_data as myhelp
importlib.reload(myhelp)

import pandas as pd
import nltk

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ## Load the data

# %% [markdown]
# The data will be loaded from a .csv file. The columns are separated with tabs.

# %%
# load training data from file
#data = myhelp.load_data("../dataset/training_data_lowercase.csv", '\t')
data = myhelp.load_data("training_data_lowercase.csv", '\t')

# load testing data from file
#data_out = myhelp.load_data("../dataset/testing_data_lowercase_nolabels.csv")
data_out = myhelp.load_data("testing_data_lowercase_nolabels.csv")

# %% [markdown]
# ## Initial visualization of the data

# %% [markdown]
# Let's get familiar with the data by starting to visualize the content.

# %%
myhelp.display_data(data)
# Out:
# Data head():
#    0                                                  1
# 0  0  donald trump sends out embarrassing new year‚s...
# 1  0  drunk bragging trump staffer started russian c...
# 2  0  sheriff david clarke becomes an internet joke ...
# 3  0  trump is so obsessed he even has obama‚s name ...
# 4  0  pope francis just called out donald trump duri...
#
# Data info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34152 entries, 0 to 34151
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       34152 non-null  int64
#  1   1       34152 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 533.8+ KB
# None
#
# Data shape:
# (34152, 2)

# %%
myhelp.display_data(data_out)
# Out:
# Data head():
#    0                                                  1
# 0  2  copycat muslim terrorist arrested with assault...
# 1  2  wow! chicago protester caught on camera admits...
# 2  2   germany's fdp look to fill schaeuble's big shoes
# 3  2  mi school sends welcome back packet warning ki...
# 4  2  u.n. seeks 'massive' aid boost amid rohingya '...
#
# Data info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9984 entries, 0 to 9983
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       9984 non-null   object
#  1   1       9984 non-null   object
# dtypes: object(2)
# memory usage: 156.1+ KB
# None
#
# Data shape:
# (9984, 2)

# %% [markdown]
# ## Set names for the columns

# %%
data.columns = ['label', 'article']
data_out.columns = ['label', 'article']

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Observations:
# - The data is already lower-case.

# %% [markdown]
# ### Stopwords

# %%
import nltk
#nltk.download()   # try to use this is you need some package
nltk.download('stopwords', download_dir='/root/nltk_data') # Google colab: try to use this is you need some package
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
print (stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %% [markdown]
# ### Tokenization

# %%
#import nltk
nltk.download('punkt_tab') # try to use this is you need some package
nltk.download('punkt_tab', download_dir='/root/nltk_data') # Google colab: try to use this is you need some package
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
data['token'] = data.apply(
    lambda row: myhelp.tokenizer_and_remove_punctuation(row, 'article'),
    axis=1
    )
data.head()
# Out:
#    label                                            article  \
# 0      0  donald trump sends out embarrassing new year‚s...
# 1      0  drunk bragging trump staffer started russian c...
# 2      0  sheriff david clarke becomes an internet joke ...
# 3      0  trump is so obsessed he even has obama‚s name ...
# 4      0  pope francis just called out donald trump duri...
#
#                                                token
# 0  [donald, trump, sends, out, embarrassing, new,...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, is, so, obsessed, he, even, has, name,...
# 4  [pope, francis, just, called, out, donald, tru...

# %%
data_out['token'] = data_out.apply(
    lambda row: myhelp.tokenizer_and_remove_punctuation(row, 'article'),
    axis=1
    )
data_out.head()
# Out:
#   label                                            article  \
# 0     2  copycat muslim terrorist arrested with assault...
# 1     2  wow! chicago protester caught on camera admits...
# 2     2   germany's fdp look to fill schaeuble's big shoes
# 3     2  mi school sends welcome back packet warning ki...
# 4     2  u.n. seeks 'massive' aid boost amid rohingya '...
#
#                                                token
# 0  [copycat, muslim, terrorist, arrested, with, a...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seeks, aid, boost, amid, rohingya, within, an...

# %% [markdown]
# ### Stemming

# %%
# stemming applied to all articles
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

#stemmer_porter   = PorterStemmer()
stemmer = SnowballStemmer('english')

data['stem'] = data.apply(
    lambda row: myhelp.stemming(stemmer, row, 'token'),
    axis=1
    )
data.head()
# Out:
#    label                                            article  \
# 0      0  donald trump sends out embarrassing new year‚s...
# 1      0  drunk bragging trump staffer started russian c...
# 2      0  sheriff david clarke becomes an internet joke ...
# 3      0  trump is so obsessed he even has obama‚s name ...
# 4      0  pope francis just called out donald trump duri...
#
#                                                token  \
# 0  [donald, trump, sends, out, embarrassing, new,...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, is, so, obsessed, he, even, has, name,...
# 4  [pope, francis, just, called, out, donald, tru...
#
#                                                 stem
# 0  [donald, trump, send, out, embarrass, new, eve...
# 1  [drunk, brag, trump, staffer, start, russian, ...
# 2  [sheriff, david, clark, becom, an, internet, j...
# 3  [trump, is, so, obsess, he, even, has, name, c...
# 4  [pope, franci, just, call, out, donald, trump,...

# %%
data_out['stem'] = data_out.apply(
    lambda row: myhelp.stemming(stemmer, row, 'token'),
    axis=1
    )
data_out.head()
# Out:
#   label                                            article  \
# 0     2  copycat muslim terrorist arrested with assault...
# 1     2  wow! chicago protester caught on camera admits...
# 2     2   germany's fdp look to fill schaeuble's big shoes
# 3     2  mi school sends welcome back packet warning ki...
# 4     2  u.n. seeks 'massive' aid boost amid rohingya '...
#
#                                                token  \
# 0  [copycat, muslim, terrorist, arrested, with, a...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seeks, aid, boost, amid, rohingya, within, an...
#
#                                                 stem
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protest, caught, on, camera, ad...
# 2  [germani, fdp, look, to, fill, schaeubl, big, ...
# 3  [mi, school, send, welcom, back, packet, warn,...
# 4  [seek, aid, boost, amid, rohingya, within, an,...

# %% [markdown]
# ### Lemmatization

# %%
#import nltk
#nltk.download('averaged_perceptron_tagger_eng') # try to use this is you need some package
#nltk.download('wordnet') # wordnet is the most well known lemmatizer for english
#nltk.download('omw-1.4')

# Google colab: try to use this is you need some package
nltk.download('averaged_perceptron_tagger_eng', download_dir='/root/nltk_data')
nltk.download('wordnet', download_dir='/root/nltk_data') # wordnet is the most well known lemmatizer for english
nltk.download('omw-1.4', download_dir='/root/nltk_data')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# lemmatize with part of speech helpers
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

data['lemma'] = data.apply(
    lambda row: myhelp.lemmatizer_with_pos(lemmatizer, row, 'token'),
    axis=1
    )
data.head()
# Out:
#    label                                            article  \
# 0      0  donald trump sends out embarrassing new year‚s...
# 1      0  drunk bragging trump staffer started russian c...
# 2      0  sheriff david clarke becomes an internet joke ...
# 3      0  trump is so obsessed he even has obama‚s name ...
# 4      0  pope francis just called out donald trump duri...
#
#                                                token  \
# 0  [donald, trump, sends, out, embarrassing, new,...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, is, so, obsessed, he, even, has, name,...
# 4  [pope, francis, just, called, out, donald, tru...
#
#                                                 stem  \
# 0  [donald, trump, send, out, embarrass, new, eve...
# 1  [drunk, brag, trump, staffer, start, russian, ...
# 2  [sheriff, david, clark, becom, an, internet, j...
# 3  [trump, is, so, obsess, he, even, has, name, c...
# 4  [pope, franci, just, call, out, donald, trump,...
#
#                                                lemma
# 0  [donald, trump, sends, out, embarrass, new, ev...
# 1  [drunk, bragging, trump, staffer, start, russi...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, be, so, obsess, he, even, have, name, ...
# 4  [pope, francis, just, call, out, donald, trump...

# %%
data_out['lemma'] = data_out.apply(
    lambda row: myhelp.lemmatizer_with_pos(lemmatizer, row, 'token'),
    axis=1
    )
data_out.head()
# Out:
#   label                                            article  \
# 0     2  copycat muslim terrorist arrested with assault...
# 1     2  wow! chicago protester caught on camera admits...
# 2     2   germany's fdp look to fill schaeuble's big shoes
# 3     2  mi school sends welcome back packet warning ki...
# 4     2  u.n. seeks 'massive' aid boost amid rohingya '...
#
#                                                token  \
# 0  [copycat, muslim, terrorist, arrested, with, a...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seeks, aid, boost, amid, rohingya, within, an...
#
#                                                 stem  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protest, caught, on, camera, ad...
# 2  [germani, fdp, look, to, fill, schaeubl, big, ...
# 3  [mi, school, send, welcom, back, packet, warn,...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                                lemma
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seek, aid, boost, amid, rohingya, within, an,...

# %% [markdown]
# ### Remove stop words

# %%
# data train: remove stopwords for tokenization
data['token_no_sw'] = data.apply(
  lambda row: myhelp.remove_stopwords(stopwords, row, 'token'),
  axis=1)
data.head()
# Out:
#    label                                            article  \
# 0      0  donald trump sends out embarrassing new year‚s...
# 1      0  drunk bragging trump staffer started russian c...
# 2      0  sheriff david clarke becomes an internet joke ...
# 3      0  trump is so obsessed he even has obama‚s name ...
# 4      0  pope francis just called out donald trump duri...
#
#                                                token  \
# 0  [donald, trump, sends, out, embarrassing, new,...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, is, so, obsessed, he, even, has, name,...
# 4  [pope, francis, just, called, out, donald, tru...
#
#                                                 stem  \
# 0  [donald, trump, send, out, embarrass, new, eve...
# 1  [drunk, brag, trump, staffer, start, russian, ...
# 2  [sheriff, david, clark, becom, an, internet, j...
# 3  [trump, is, so, obsess, he, even, has, name, c...
# 4  [pope, franci, just, call, out, donald, trump,...
#
#                                                lemma  \
# 0  [donald, trump, sends, out, embarrass, new, ev...
# 1  [drunk, bragging, trump, staffer, start, russi...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, be, so, obsess, he, even, have, name, ...
# 4  [pope, francis, just, call, out, donald, trump...
#
#                                          token_no_sw
# 0  [eve, disturbing, embarrassing, message, sends...
# 1  [russian, started, bragging, investigation, st...
# 2  [internet, clarke, sheriff, poke, joke, threat...
# 3          [obsessed, images, website, trump, coded]
# 4  [speech, francis, christmas, called, pope, tru...

# %%
# data train: remove stopwords for stemming
data['stem_no_sw'] = data.apply(
  lambda row: myhelp.remove_stopwords(stopwords, row, 'stem'),
  axis=1)
data.head()
# Out:
#    label                                            article  \
# 0      0  donald trump sends out embarrassing new year‚s...
# 1      0  drunk bragging trump staffer started russian c...
# 2      0  sheriff david clarke becomes an internet joke ...
# 3      0  trump is so obsessed he even has obama‚s name ...
# 4      0  pope francis just called out donald trump duri...
#
#                                                token  \
# 0  [donald, trump, sends, out, embarrassing, new,...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, is, so, obsessed, he, even, has, name,...
# 4  [pope, francis, just, called, out, donald, tru...
#
#                                                 stem  \
# 0  [donald, trump, send, out, embarrass, new, eve...
# 1  [drunk, brag, trump, staffer, start, russian, ...
# 2  [sheriff, david, clark, becom, an, internet, j...
# 3  [trump, is, so, obsess, he, even, has, name, c...
# 4  [pope, franci, just, call, out, donald, trump,...
#
#                                                lemma  \
# 0  [donald, trump, sends, out, embarrass, new, ev...
# 1  [drunk, bragging, trump, staffer, start, russi...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, be, so, obsess, he, even, have, name, ...
# 4  [pope, francis, just, call, out, donald, trump...
#
#                                          token_no_sw  \
# 0  [eve, disturbing, embarrassing, message, sends...
# 1  [russian, started, bragging, investigation, st...
# 2  [internet, clarke, sheriff, poke, joke, threat...
# 3          [obsessed, images, website, trump, coded]
# 4  [speech, francis, christmas, called, pope, tru...
#
#                                           stem_no_sw
# 0  [eve, donald, disturb, embarrass, messag, trum...
# 1  [russian, investig, start, staffer, drunk, col...
# 2  [internet, sheriff, poke, threaten, joke, beco...
# 3                [obsess, code, websit, trump, imag]
# 4  [dure, christma, speech, pope, trump, franci, ...

# %%
# data train: remove stopwords for lemmatization
data['lemma_no_sw'] = data.apply(
  lambda row: myhelp.remove_stopwords(stopwords, row, 'lemma'),
  axis=1)
data.head()
# Out:
#    label                                            article  \
# 0      0  donald trump sends out embarrassing new year‚s...
# 1      0  drunk bragging trump staffer started russian c...
# 2      0  sheriff david clarke becomes an internet joke ...
# 3      0  trump is so obsessed he even has obama‚s name ...
# 4      0  pope francis just called out donald trump duri...
#
#                                                token  \
# 0  [donald, trump, sends, out, embarrassing, new,...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, is, so, obsessed, he, even, has, name,...
# 4  [pope, francis, just, called, out, donald, tru...
#
#                                                 stem  \
# 0  [donald, trump, send, out, embarrass, new, eve...
# 1  [drunk, brag, trump, staffer, start, russian, ...
# 2  [sheriff, david, clark, becom, an, internet, j...
# 3  [trump, is, so, obsess, he, even, has, name, c...
# 4  [pope, franci, just, call, out, donald, trump,...
#
#                                                lemma  \
# 0  [donald, trump, sends, out, embarrass, new, ev...
# 1  [drunk, bragging, trump, staffer, start, russi...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, be, so, obsess, he, even, have, name, ...
# 4  [pope, francis, just, call, out, donald, trump...
#
#                                          token_no_sw  \
# 0  [eve, disturbing, embarrassing, message, sends...
# 1  [russian, started, bragging, investigation, st...
# 2  [internet, clarke, sheriff, poke, joke, threat...
# 3          [obsessed, images, website, trump, coded]
# 4  [speech, francis, christmas, called, pope, tru...
#
#                                           stem_no_sw  \
# 0  [eve, donald, disturb, embarrass, messag, trum...
# 1  [russian, investig, start, staffer, drunk, col...
# 2  [internet, sheriff, poke, threaten, joke, beco...
# 3                [obsess, code, websit, trump, imag]
# 4  [dure, christma, speech, pope, trump, franci, ...
#
#                                          lemma_no_sw
# 0  [eve, message, disturb, sends, embarrass, trum...
# 1  [russian, start, investigation, bragging, staf...
# 2  [internet, clarke, sheriff, poke, threaten, jo...
# 3               [image, obsess, website, trump, cod]
# 4  [speech, francis, christmas, pope, trump, call...

# %%
# data test: remove stopwords for tokenization
data_out['token_no_sw'] = data_out.apply(
  lambda row: myhelp.remove_stopwords(stopwords, row, 'token'),
  axis=1)
data_out.head()
# Out:
#   label                                            article  \
# 0     2  copycat muslim terrorist arrested with assault...
# 1     2  wow! chicago protester caught on camera admits...
# 2     2   germany's fdp look to fill schaeuble's big shoes
# 3     2  mi school sends welcome back packet warning ki...
# 4     2  u.n. seeks 'massive' aid boost amid rohingya '...
#
#                                                token  \
# 0  [copycat, muslim, terrorist, arrested, with, a...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seeks, aid, boost, amid, rohingya, within, an...
#
#                                                 stem  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protest, caught, on, camera, ad...
# 2  [germani, fdp, look, to, fill, schaeubl, big, ...
# 3  [mi, school, send, welcom, back, packet, warn,...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                                lemma  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                          token_no_sw
# 0  [weapons, terrorist, assault, muslim, copycat,...
# 1  [caught, activity, admits, violent, chicago, w...
# 2        [schaeuble, fdp, fill, big, shoes, germany]
# 3  [back, warning, packet, sends, welcome, flag, ...
# 4     [amid, seeks, boost, emergency, aid, rohingya]

# %%
# data test: remove stopwords for stemming
data_out['stem_no_sw'] = data_out.apply(
  lambda row: myhelp.remove_stopwords(stopwords, row, 'stem'),
  axis=1)
data_out.head()
# Out:
#   label                                            article  \
# 0     2  copycat muslim terrorist arrested with assault...
# 1     2  wow! chicago protester caught on camera admits...
# 2     2   germany's fdp look to fill schaeuble's big shoes
# 3     2  mi school sends welcome back packet warning ki...
# 4     2  u.n. seeks 'massive' aid boost amid rohingya '...
#
#                                                token  \
# 0  [copycat, muslim, terrorist, arrested, with, a...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seeks, aid, boost, amid, rohingya, within, an...
#
#                                                 stem  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protest, caught, on, camera, ad...
# 2  [germani, fdp, look, to, fill, schaeubl, big, ...
# 3  [mi, school, send, welcom, back, packet, warn,...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                                lemma  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                          token_no_sw  \
# 0  [weapons, terrorist, assault, muslim, copycat,...
# 1  [caught, activity, admits, violent, chicago, w...
# 2        [schaeuble, fdp, fill, big, shoes, germany]
# 3  [back, warning, packet, sends, welcome, flag, ...
# 4     [amid, seeks, boost, emergency, aid, rohingya]
#
#                                           stem_no_sw
# 0  [terrorist, weapon, assault, muslim, copycat, ...
# 1  [caught, violent, chicago, wow, protest, gon, ...
# 2          [germani, fdp, fill, big, shoe, schaeubl]
# 3  [wear, warn, back, welcom, packet, kid, flag, ...
# 4          [amid, seek, boost, aid, emerg, rohingya]

# %%
# data test: remove stopwords for lemmatization
data_out['lemma_no_sw'] = data_out.apply(
  lambda row: myhelp.remove_stopwords(stopwords, row, 'lemma'),
  axis=1)
data_out.head()
# Out:
#   label                                            article  \
# 0     2  copycat muslim terrorist arrested with assault...
# 1     2  wow! chicago protester caught on camera admits...
# 2     2   germany's fdp look to fill schaeuble's big shoes
# 3     2  mi school sends welcome back packet warning ki...
# 4     2  u.n. seeks 'massive' aid boost amid rohingya '...
#
#                                                token  \
# 0  [copycat, muslim, terrorist, arrested, with, a...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seeks, aid, boost, amid, rohingya, within, an...
#
#                                                 stem  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protest, caught, on, camera, ad...
# 2  [germani, fdp, look, to, fill, schaeubl, big, ...
# 3  [mi, school, send, welcom, back, packet, warn,...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                                lemma  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                          token_no_sw  \
# 0  [weapons, terrorist, assault, muslim, copycat,...
# 1  [caught, activity, admits, violent, chicago, w...
# 2        [schaeuble, fdp, fill, big, shoes, germany]
# 3  [back, warning, packet, sends, welcome, flag, ...
# 4     [amid, seeks, boost, emergency, aid, rohingya]
#
#                                           stem_no_sw  \
# 0  [terrorist, weapon, assault, muslim, copycat, ...
# 1  [caught, violent, chicago, wow, protest, gon, ...
# 2          [germani, fdp, fill, big, shoe, schaeubl]
# 3  [wear, warn, back, welcom, packet, kid, flag, ...
# 4          [amid, seek, boost, aid, emerg, rohingya]
#
#                                          lemma_no_sw
# 0  [terrorist, weapon, assault, muslim, copycat, ...
# 1  [caught, activity, admits, violent, chicago, w...
# 2         [schaeuble, fdp, fill, big, shoe, germany]
# 3  [wear, warn, back, packet, sends, kid, welcome...
# 4      [amid, seek, boost, emergency, aid, rohingya]

# %% [markdown]
# ### Merge preprocessed data to suit classification
#
# ---

# %%
# put all this cleaning together

#def re_blob(row):
#  return " ".join(row['no_stopwords'])

# data train: make a blob for tokenizer
data['token_blob'] = data.apply(
    lambda row: myhelp.re_blob(row, 'token_no_sw'),
    axis=1
    )
data.head()

#data_out['clean_blob'] = data_out.apply(re_blob,axis=1)
#data_out.head()
# Out:
#    label                                            article  \
# 0      0  donald trump sends out embarrassing new year‚s...
# 1      0  drunk bragging trump staffer started russian c...
# 2      0  sheriff david clarke becomes an internet joke ...
# 3      0  trump is so obsessed he even has obama‚s name ...
# 4      0  pope francis just called out donald trump duri...
#
#                                                token  \
# 0  [donald, trump, sends, out, embarrassing, new,...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, is, so, obsessed, he, even, has, name,...
# 4  [pope, francis, just, called, out, donald, tru...
#
#                                                 stem  \
# 0  [donald, trump, send, out, embarrass, new, eve...
# 1  [drunk, brag, trump, staffer, start, russian, ...
# 2  [sheriff, david, clark, becom, an, internet, j...
# 3  [trump, is, so, obsess, he, even, has, name, c...
# 4  [pope, franci, just, call, out, donald, trump,...
#
#                                                lemma  \
# 0  [donald, trump, sends, out, embarrass, new, ev...
# 1  [drunk, bragging, trump, staffer, start, russi...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, be, so, obsess, he, even, have, name, ...
# 4  [pope, francis, just, call, out, donald, trump...
#
#                                          token_no_sw  \
# 0  [eve, disturbing, embarrassing, message, sends...
# 1  [russian, started, bragging, investigation, st...
# 2  [internet, clarke, sheriff, poke, joke, threat...
# 3          [obsessed, images, website, trump, coded]
# 4  [speech, francis, christmas, called, pope, tru...
#
#                                           stem_no_sw  \
# 0  [eve, donald, disturb, embarrass, messag, trum...
# 1  [russian, investig, start, staffer, drunk, col...
# 2  [internet, sheriff, poke, threaten, joke, beco...
# 3                [obsess, code, websit, trump, imag]
# 4  [dure, christma, speech, pope, trump, franci, ...
#
#                                          lemma_no_sw  \
# 0  [eve, message, disturb, sends, embarrass, trum...
# 1  [russian, start, investigation, bragging, staf...
# 2  [internet, clarke, sheriff, poke, threaten, jo...
# 3               [image, obsess, website, trump, cod]
# 4  [speech, francis, christmas, pope, trump, call...
#
#                                           token_blob
# 0  eve disturbing embarrassing message sends trum...
# 1  russian started bragging investigation staffer...
# 2  internet clarke sheriff poke joke threatening ...
# 3                obsessed images website trump coded
# 4  speech francis christmas called pope trump donald

# %%
# data train: make a blob for stemming
data['stem_blob'] = data.apply(
    lambda row: myhelp.re_blob(row, 'stem_no_sw'),
    axis=1
    )
data.head()
# Out:
#    label                                            article  \
# 0      0  donald trump sends out embarrassing new year‚s...
# 1      0  drunk bragging trump staffer started russian c...
# 2      0  sheriff david clarke becomes an internet joke ...
# 3      0  trump is so obsessed he even has obama‚s name ...
# 4      0  pope francis just called out donald trump duri...
#
#                                                token  \
# 0  [donald, trump, sends, out, embarrassing, new,...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, is, so, obsessed, he, even, has, name,...
# 4  [pope, francis, just, called, out, donald, tru...
#
#                                                 stem  \
# 0  [donald, trump, send, out, embarrass, new, eve...
# 1  [drunk, brag, trump, staffer, start, russian, ...
# 2  [sheriff, david, clark, becom, an, internet, j...
# 3  [trump, is, so, obsess, he, even, has, name, c...
# 4  [pope, franci, just, call, out, donald, trump,...
#
#                                                lemma  \
# 0  [donald, trump, sends, out, embarrass, new, ev...
# 1  [drunk, bragging, trump, staffer, start, russi...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, be, so, obsess, he, even, have, name, ...
# 4  [pope, francis, just, call, out, donald, trump...
#
#                                          token_no_sw  \
# 0  [eve, disturbing, embarrassing, message, sends...
# 1  [russian, started, bragging, investigation, st...
# 2  [internet, clarke, sheriff, poke, joke, threat...
# 3          [obsessed, images, website, trump, coded]
# 4  [speech, francis, christmas, called, pope, tru...
#
#                                           stem_no_sw  \
# 0  [eve, donald, disturb, embarrass, messag, trum...
# 1  [russian, investig, start, staffer, drunk, col...
# 2  [internet, sheriff, poke, threaten, joke, beco...
# 3                [obsess, code, websit, trump, imag]
# 4  [dure, christma, speech, pope, trump, franci, ...
#
#                                          lemma_no_sw  \
# 0  [eve, message, disturb, sends, embarrass, trum...
# 1  [russian, start, investigation, bragging, staf...
# 2  [internet, clarke, sheriff, poke, threaten, jo...
# 3               [image, obsess, website, trump, cod]
# 4  [speech, francis, christmas, pope, trump, call...
#
#                                           token_blob  \
# 0  eve disturbing embarrassing message sends trum...
# 1  russian started bragging investigation staffer...
# 2  internet clarke sheriff poke joke threatening ...
# 3                obsessed images website trump coded
# 4  speech francis christmas called pope trump donald
#
#                                            stem_blob
# 0     eve donald disturb embarrass messag trump send
# 1  russian investig start staffer drunk collus tr...
# 2  internet sheriff poke threaten joke becom davi...
# 3                      obsess code websit trump imag
# 4  dure christma speech pope trump franci call do...

# %%
# data train: make a blob for lemmatizer
data['lemma_blob'] = data.apply(
    lambda row: myhelp.re_blob(row, 'lemma_no_sw'),
    axis=1
    )
data.head()
# Out:
#    label                                            article  \
# 0      0  donald trump sends out embarrassing new year‚s...
# 1      0  drunk bragging trump staffer started russian c...
# 2      0  sheriff david clarke becomes an internet joke ...
# 3      0  trump is so obsessed he even has obama‚s name ...
# 4      0  pope francis just called out donald trump duri...
#
#                                                token  \
# 0  [donald, trump, sends, out, embarrassing, new,...
# 1  [drunk, bragging, trump, staffer, started, rus...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, is, so, obsessed, he, even, has, name,...
# 4  [pope, francis, just, called, out, donald, tru...
#
#                                                 stem  \
# 0  [donald, trump, send, out, embarrass, new, eve...
# 1  [drunk, brag, trump, staffer, start, russian, ...
# 2  [sheriff, david, clark, becom, an, internet, j...
# 3  [trump, is, so, obsess, he, even, has, name, c...
# 4  [pope, franci, just, call, out, donald, trump,...
#
#                                                lemma  \
# 0  [donald, trump, sends, out, embarrass, new, ev...
# 1  [drunk, bragging, trump, staffer, start, russi...
# 2  [sheriff, david, clarke, becomes, an, internet...
# 3  [trump, be, so, obsess, he, even, have, name, ...
# 4  [pope, francis, just, call, out, donald, trump...
#
#                                          token_no_sw  \
# 0  [eve, disturbing, embarrassing, message, sends...
# 1  [russian, started, bragging, investigation, st...
# 2  [internet, clarke, sheriff, poke, joke, threat...
# 3          [obsessed, images, website, trump, coded]
# 4  [speech, francis, christmas, called, pope, tru...
#
#                                           stem_no_sw  \
# 0  [eve, donald, disturb, embarrass, messag, trum...
# 1  [russian, investig, start, staffer, drunk, col...
# 2  [internet, sheriff, poke, threaten, joke, beco...
# 3                [obsess, code, websit, trump, imag]
# 4  [dure, christma, speech, pope, trump, franci, ...
#
#                                          lemma_no_sw  \
# 0  [eve, message, disturb, sends, embarrass, trum...
# 1  [russian, start, investigation, bragging, staf...
# 2  [internet, clarke, sheriff, poke, threaten, jo...
# 3               [image, obsess, website, trump, cod]
# 4  [speech, francis, christmas, pope, trump, call...
#
#                                           token_blob  \
# 0  eve disturbing embarrassing message sends trum...
# 1  russian started bragging investigation staffer...
# 2  internet clarke sheriff poke joke threatening ...
# 3                obsessed images website trump coded
# 4  speech francis christmas called pope trump donald
#
#                                            stem_blob  \
# 0     eve donald disturb embarrass messag trump send
# 1  russian investig start staffer drunk collus tr...
# 2  internet sheriff poke threaten joke becom davi...
# 3                      obsess code websit trump imag
# 4  dure christma speech pope trump franci call do...
#
#                                           lemma_blob
# 0   eve message disturb sends embarrass trump donald
# 1  russian start investigation bragging staffer d...
# 2   internet clarke sheriff poke threaten joke david
# 3                     image obsess website trump cod
# 4    speech francis christmas pope trump call donald

# %%
# data test: make a blob for tokenizer
data_out['token_blob'] = data_out.apply(
    lambda row: myhelp.re_blob(row, 'token_no_sw'),
    axis=1
    )
data_out.head()
# Out:
#   label                                            article  \
# 0     2  copycat muslim terrorist arrested with assault...
# 1     2  wow! chicago protester caught on camera admits...
# 2     2   germany's fdp look to fill schaeuble's big shoes
# 3     2  mi school sends welcome back packet warning ki...
# 4     2  u.n. seeks 'massive' aid boost amid rohingya '...
#
#                                                token  \
# 0  [copycat, muslim, terrorist, arrested, with, a...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seeks, aid, boost, amid, rohingya, within, an...
#
#                                                 stem  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protest, caught, on, camera, ad...
# 2  [germani, fdp, look, to, fill, schaeubl, big, ...
# 3  [mi, school, send, welcom, back, packet, warn,...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                                lemma  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                          token_no_sw  \
# 0  [weapons, terrorist, assault, muslim, copycat,...
# 1  [caught, activity, admits, violent, chicago, w...
# 2        [schaeuble, fdp, fill, big, shoes, germany]
# 3  [back, warning, packet, sends, welcome, flag, ...
# 4     [amid, seeks, boost, emergency, aid, rohingya]
#
#                                           stem_no_sw  \
# 0  [terrorist, weapon, assault, muslim, copycat, ...
# 1  [caught, violent, chicago, wow, protest, gon, ...
# 2          [germani, fdp, fill, big, shoe, schaeubl]
# 3  [wear, warn, back, welcom, packet, kid, flag, ...
# 4          [amid, seek, boost, aid, emerg, rohingya]
#
#                                          lemma_no_sw  \
# 0  [terrorist, weapon, assault, muslim, copycat, ...
# 1  [caught, activity, admits, violent, chicago, w...
# 2         [schaeuble, fdp, fill, big, shoe, germany]
# 3  [wear, warn, back, packet, sends, kid, welcome...
# 4      [amid, seek, boost, emergency, aid, rohingya]
#
#                                           token_blob
# 0  weapons terrorist assault muslim copycat arrested
# 1  caught activity admits violent chicago wow gon...
# 2               schaeuble fdp fill big shoes germany
# 3  back warning packet sends welcome flag kids sc...
# 4            amid seeks boost emergency aid rohingya

# %%
# data test: make a blob for stemming
data_out['stem_blob'] = data_out.apply(
    lambda row: myhelp.re_blob(row, 'stem_no_sw'),
    axis=1
    )
data_out.head()
# Out:
#   label                                            article  \
# 0     2  copycat muslim terrorist arrested with assault...
# 1     2  wow! chicago protester caught on camera admits...
# 2     2   germany's fdp look to fill schaeuble's big shoes
# 3     2  mi school sends welcome back packet warning ki...
# 4     2  u.n. seeks 'massive' aid boost amid rohingya '...
#
#                                                token  \
# 0  [copycat, muslim, terrorist, arrested, with, a...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seeks, aid, boost, amid, rohingya, within, an...
#
#                                                 stem  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protest, caught, on, camera, ad...
# 2  [germani, fdp, look, to, fill, schaeubl, big, ...
# 3  [mi, school, send, welcom, back, packet, warn,...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                                lemma  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                          token_no_sw  \
# 0  [weapons, terrorist, assault, muslim, copycat,...
# 1  [caught, activity, admits, violent, chicago, w...
# 2        [schaeuble, fdp, fill, big, shoes, germany]
# 3  [back, warning, packet, sends, welcome, flag, ...
# 4     [amid, seeks, boost, emergency, aid, rohingya]
#
#                                           stem_no_sw  \
# 0  [terrorist, weapon, assault, muslim, copycat, ...
# 1  [caught, violent, chicago, wow, protest, gon, ...
# 2          [germani, fdp, fill, big, shoe, schaeubl]
# 3  [wear, warn, back, welcom, packet, kid, flag, ...
# 4          [amid, seek, boost, aid, emerg, rohingya]
#
#                                          lemma_no_sw  \
# 0  [terrorist, weapon, assault, muslim, copycat, ...
# 1  [caught, activity, admits, violent, chicago, w...
# 2         [schaeuble, fdp, fill, big, shoe, germany]
# 3  [wear, warn, back, packet, sends, kid, welcome...
# 4      [amid, seek, boost, emergency, aid, rohingya]
#
#                                           token_blob  \
# 0  weapons terrorist assault muslim copycat arrested
# 1  caught activity admits violent chicago wow gon...
# 2               schaeuble fdp fill big shoes germany
# 3  back warning packet sends welcome flag kids sc...
# 4            amid seeks boost emergency aid rohingya
#
#                                            stem_blob
# 0     terrorist weapon assault muslim copycat arrest
# 1  caught violent chicago wow protest gon admit c...
# 2                 germani fdp fill big shoe schaeubl
# 3  wear warn back welcom packet kid flag school send
# 4                 amid seek boost aid emerg rohingya

# %%
# data test: make a blob for lemmatizer
data_out['lemma_blob'] = data_out.apply(
    lambda row: myhelp.re_blob(row, 'lemma_no_sw'),
    axis=1
    )
data_out.head()
# Out:
#   label                                            article  \
# 0     2  copycat muslim terrorist arrested with assault...
# 1     2  wow! chicago protester caught on camera admits...
# 2     2   germany's fdp look to fill schaeuble's big shoes
# 3     2  mi school sends welcome back packet warning ki...
# 4     2  u.n. seeks 'massive' aid boost amid rohingya '...
#
#                                                token  \
# 0  [copycat, muslim, terrorist, arrested, with, a...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seeks, aid, boost, amid, rohingya, within, an...
#
#                                                 stem  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protest, caught, on, camera, ad...
# 2  [germani, fdp, look, to, fill, schaeubl, big, ...
# 3  [mi, school, send, welcom, back, packet, warn,...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                                lemma  \
# 0  [copycat, muslim, terrorist, arrest, with, ass...
# 1  [wow, chicago, protester, caught, on, camera, ...
# 2  [germany, fdp, look, to, fill, schaeuble, big,...
# 3  [mi, school, sends, welcome, back, packet, war...
# 4  [seek, aid, boost, amid, rohingya, within, an,...
#
#                                          token_no_sw  \
# 0  [weapons, terrorist, assault, muslim, copycat,...
# 1  [caught, activity, admits, violent, chicago, w...
# 2        [schaeuble, fdp, fill, big, shoes, germany]
# 3  [back, warning, packet, sends, welcome, flag, ...
# 4     [amid, seeks, boost, emergency, aid, rohingya]
#
#                                           stem_no_sw  \
# 0  [terrorist, weapon, assault, muslim, copycat, ...
# 1  [caught, violent, chicago, wow, protest, gon, ...
# 2          [germani, fdp, fill, big, shoe, schaeubl]
# 3  [wear, warn, back, welcom, packet, kid, flag, ...
# 4          [amid, seek, boost, aid, emerg, rohingya]
#
#                                          lemma_no_sw  \
# 0  [terrorist, weapon, assault, muslim, copycat, ...
# 1  [caught, activity, admits, violent, chicago, w...
# 2         [schaeuble, fdp, fill, big, shoe, germany]
# 3  [wear, warn, back, packet, sends, kid, welcome...
# 4      [amid, seek, boost, emergency, aid, rohingya]
#
#                                           token_blob  \
# 0  weapons terrorist assault muslim copycat arrested
# 1  caught activity admits violent chicago wow gon...
# 2               schaeuble fdp fill big shoes germany
# 3  back warning packet sends welcome flag kids sc...
# 4            amid seeks boost emergency aid rohingya
#
#                                            stem_blob  \
# 0     terrorist weapon assault muslim copycat arrest
# 1  caught violent chicago wow protest gon admit c...
# 2                 germani fdp fill big shoe schaeubl
# 3  wear warn back welcom packet kid flag school send
# 4                 amid seek boost aid emerg rohingya
#
#                                           lemma_blob
# 0     terrorist weapon assault muslim copycat arrest
# 1  caught activity admits violent chicago wow gon...
# 2                schaeuble fdp fill big shoe germany
# 3  wear warn back packet sends kid welcome flag s...
# 4             amid seek boost emergency aid rohingya

# %% [markdown]
# ## Split the train dataset

# %%
from sklearn.model_selection import train_test_split

# tokenization: split the train dataset in train and validation sets
X_train_text_token, X_val_text_token, y_train_token, y_val_token = train_test_split(
    data['token_blob'],
    data['label'],
    test_size=0.1,
    random_state=42
    )

# %%
# stemming: split the train dataset in train and validation sets
X_train_text_stem, X_val_text_stem, y_train_stem, y_val_stem = train_test_split(
    data['stem_blob'],
    data['label'],
    test_size=0.1,
    random_state=42
    )

# %%
# lemmatization: split the train dataset in train and validation sets
X_train_text_lemma, X_val_text_lemma, y_train_lemma, y_val_lemma = train_test_split(
    data['lemma_blob'],
    data['label'],
    test_size=0.1,
    random_state=42
    )

# %%
# no preprocessing: split the train dataset in train and validation sets
X_train_text_raw, X_val_text_raw, y_train_raw, y_val_raw = train_test_split(
    data['article'],
    data['label'],
    test_size=0.1,
    random_state=42
    )

# %% [markdown]
# ## Select a classifier

# %%
# tokenization
#let's take only the most common 1000 words
from sklearn.feature_extraction.text import CountVectorizer

token_bow_vect = CountVectorizer(max_features=1000)

# fit creates one entry for each different word seen
X_train_token = token_bow_vect.fit_transform(X_train_text_token).toarray()

X_val_token = token_bow_vect.transform(X_val_text_token).toarray()

# %%
# stemming

#let's take only the most common 1000 words
stem_bow_vect = CountVectorizer(max_features=1000)

# fit creates one entry for each different word seen
X_train_stem = stem_bow_vect.fit_transform(X_train_text_stem).toarray()

X_val_stem = stem_bow_vect.transform(X_val_text_stem).toarray()

# %%
# lemmatization
#let's take only the most common 1000 words

lemma_bow_vect = CountVectorizer(max_features=1000)

# fit creates one entry for each different word seen
X_train_lemma = lemma_bow_vect.fit_transform(X_train_text_lemma).toarray()

X_val_lemma = lemma_bow_vect.transform(X_val_text_lemma).toarray()

# %%
# no preprocessing
#let's take only the most common 1000 words

raw_bow_vect = CountVectorizer(max_features=1000)

# fit creates one entry for each different word seen
X_train_raw = raw_bow_vect.fit_transform(X_train_text_raw).toarray()

X_val_raw = raw_bow_vect.transform(X_val_text_raw).toarray()

# %% [markdown]
# ## Train a Naive Bayes model

# %% [markdown]
# ### No processing

# %%
# no processing
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# create the model
bayes_raw = MultinomialNB()

# fit the model with the training set
bayes_raw.fit(X_train_raw, y_train_raw)

# evaluate the model with validation set
y_val_raw_pred = bayes_raw.predict(X_val_raw)

# display accuracy
accuracy_raw = accuracy_score(y_val_raw, y_val_raw_pred)
print("No preprocessing -> Accuracy:", accuracy_raw)
print(classification_report(y_val_raw, y_val_raw_pred))
# Out:
# No preprocessing -> Accuracy: 0.9171545667447307
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      1733
#            1       0.92      0.91      0.92      1683
#
#     accuracy                           0.92      3416
#    macro avg       0.92      0.92      0.92      3416
# weighted avg       0.92      0.92      0.92      3416

# %% [markdown]
# ### Tokenization

# %%
# tokenization

# create the model
bayes_token = MultinomialNB()

# fit the model with the training set
bayes_token.fit(X_train_token, y_train_token)

# evaluate the model with validation set
y_val_token_pred = bayes_token.predict(X_val_token)

# display accuracy
accuracy_token = accuracy_score(y_val_token, y_val_token_pred)
print("Tokenization -> Accuracy:", accuracy_token)
print(classification_report(y_val_token, y_val_token_pred))
# Out:
# Tokenization -> Accuracy: 0.8896370023419203
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89      1733
#            1       0.89      0.88      0.89      1683
#
#     accuracy                           0.89      3416
#    macro avg       0.89      0.89      0.89      3416
# weighted avg       0.89      0.89      0.89      3416

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Stemming

# %%
# stemming

# create the model
bayes_stem = MultinomialNB()

# fit the model with the training set
bayes_stem.fit(X_train_stem, y_train_stem)

# evaluate the model with validation set
y_val_stem_pred = bayes_stem.predict(X_val_stem)

# display accuracy
accuracy_stem = accuracy_score(y_val_stem, y_val_stem_pred)
print("Stemming -> Accuracy:", accuracy_stem)
print(classification_report(y_val_stem, y_val_stem_pred))
# Out:
# Stemming -> Accuracy: 0.8957845433255269
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      1733
#            1       0.90      0.89      0.89      1683
#
#     accuracy                           0.90      3416
#    macro avg       0.90      0.90      0.90      3416
# weighted avg       0.90      0.90      0.90      3416

# %% [markdown]
# ### Lemmatization

# %%
# lemmatization

# create the model
bayes_lemma = MultinomialNB()

# fit the model with the training set
bayes_lemma.fit(X_train_lemma, y_train_lemma)

# evaluate the model with validation set
y_val_lemma_pred = bayes_lemma.predict(X_val_lemma)

# display accuracy
accuracy_lemma = accuracy_score(y_val_lemma, y_val_lemma_pred)
print("Lemmatization -> Accuracy:", accuracy_lemma)
print(classification_report(y_val_lemma, y_val_lemma_pred))
# Out:
# Lemmatization -> Accuracy: 0.890807962529274
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      1733
#            1       0.89      0.89      0.89      1683
#
#     accuracy                           0.89      3416
#    macro avg       0.89      0.89      0.89      3416
# weighted avg       0.89      0.89      0.89      3416

# %% [markdown]
# ## Evaluate the model using test dataset

# %%
# lemmatization
X_test_lemma = lemma_bow_vect.transform(data_out['lemma_blob']).toarray()

# predict for test data set
y_test_lemma_pred = bayes_lemma.predict(X_test_lemma)

data_out['label'] = y_test_lemma_pred

# %% [markdown]
# ## Save the predictions to an output file

# %%
data_out[['label', 'article']].to_csv('testing_data_lowercase_labels.csv', sep='\t', index=False, header=False)

# %% [markdown]
# ## Save the models to output files

# %%
from pathlib import Path
import joblib

# Name your model here and run to save.
best_pipes = [
    bayes_raw,
    bayes_token,
    bayes_stem,
    bayes_lemma
    ]

# Define model path clearly
model_paths = [
    "bow_raw_naive_bayes.joblib",
    "bow_token_naive_bayes.joblib",
    "bow_stem_naive_bayes.joblib",
    "bow_lemma_naive_bayes.joblib"
    ]

# Save the model
for model_path, best_pipe in zip(model_paths, best_pipes):
    joblib.dump(best_pipe, model_path)

print("Models saved.")
